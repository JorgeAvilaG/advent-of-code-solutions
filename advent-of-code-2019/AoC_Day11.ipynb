opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    return operator_1 + operator_2


def opcode_mult(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    return operator_1 * operator_2


def opcode_input(opcode, pos, data, color):
    return color


def opcode_output(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        return data[data[pos + 1]]
    elif opcode[-3] == "2":
        return data[data[pos + 1] + r_pos]
    else:
        return data[pos + 1]


def opcode_jump_true(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    if operator_1 != 0:
        return operator_2
    else:
        return pos + 3


def opcode_jump_false(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    if operator_1 == 0:
        return operator_2
    else:
        return pos + 3


def opcode_less_than(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]
    if operator_1 < operator_2:
        return 1
    else:
        return 0


def opcode_equals(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]
    if operator_1 == operator_2:
        return 1
    else:
        return 0


def rel_base(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        return data[data[pos + 1]]
    elif opcode[-3] == "2":
        return data[data[pos + 1] + r_pos]
    else:
        return data[pos + 1]


directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]


def robot(position, direction, color_paint, turn_direction):
    if color_paint:
        panels[position] = 1  # white
    else:
        panels[position] = 0  # black
    if turn_direction:
        direction = (direction + 1) % 4
    else:
        direction = (direction - 1) % 4
    position = (
        position[0] + directions[direction][0],
        position[1] + directions[direction][1],
    )
    if position in panels:
        color = panels[position]
    else:
        color = 0
    return (position, direction, color)


def day11(color):
    data = d.copy()
    pos = 0
    r_pos = 0

    outputs = []
    position = (0, 0)
    direction = 0
    # color = 0 #color black

    while data[pos] != 99:
        opcode = "0" * 10 + str(data[pos])
        if opcode[-1] == "1":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_add(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_add(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "2":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_mult(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_mult(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "3":
            if opcode[-3] == "0":
                data[data[pos + 1]] = opcode_input(opcode, pos, data, color)
            elif opcode[-3] == "2":
                data[data[pos + 1] + r_pos] = opcode_input(opcode, pos, data, color)
            pos += 2
        if opcode[-1] == "4":
            outputs.append(opcode_output(opcode, pos, r_pos, data))
            pos += 2
        if opcode[-1] == "5":
            pos = opcode_jump_true(opcode, pos, r_pos, data)
        if opcode[-1] == "6":
            pos = opcode_jump_false(opcode, pos, r_pos, data)
        if opcode[-1] == "7":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_less_than(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_less_than(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "8":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_equals(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_equals(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "9":
            r_pos += rel_base(opcode, pos, r_pos, data)
            pos += 2

        if len(outputs) == 2:
            # print(outputs)
            position, direction, color = robot(
                position, direction, outputs[0], outputs[1]
            )
            # print(position, direction, color)
            outputs = []


# Part 1
panels = {}
day11(0)
print("Solution Part 1:", len(panels))

# Part 2
print("Part 2")
panels = {}
day11(1)

x = []
y = []
for item in panels:
    if panels[item] == 1:

        x.append(item[0])
        y.append(item[1])
import numpy as np
import matplotlib.pyplot as plt

matrix = [[0] * 40] * 6
matrix = np.matrix(matrix)
for i in range(len(x)):
    matrix[-x[i], y[i]] = 1

plt.imshow(matrix, cmap="hot")
plt.show()
# Out:
# Solution Part 1: 1732
# Part 2
