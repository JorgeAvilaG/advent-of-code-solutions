# %%
raw_d = "3,8,1001,8,10,8,105,1,0,0,21,34,47,72,93,110,191,272,353,434,99999,3,9,102,3,9,9,1001,9,3,9,4,9,99,3,9,102,4,9,9,1001,9,4,9,4,9,99,3,9,101,3,9,9,1002,9,3,9,1001,9,2,9,1002,9,2,9,101,4,9,9,4,9,99,3,9,1002,9,3,9,101,5,9,9,102,4,9,9,1001,9,4,9,4,9,99,3,9,101,3,9,9,102,4,9,9,1001,9,3,9,4,9,99,3,9,101,2,9,9,4,9,3,9,1001,9,2,9,4,9,3,9,101,2,9,9,4,9,3,9,1002,9,2,9,4,9,3,9,102,2,9,9,4,9,3,9,1002,9,2,9,4,9,3,9,102,2,9,9,4,9,3,9,101,1,9,9,4,9,3,9,1002,9,2,9,4,9,3,9,1002,9,2,9,4,9,99,3,9,102,2,9,9,4,9,3,9,1002,9,2,9,4,9,3,9,102,2,9,9,4,9,3,9,1002,9,2,9,4,9,3,9,1001,9,1,9,4,9,3,9,1001,9,2,9,4,9,3,9,102,2,9,9,4,9,3,9,101,1,9,9,4,9,3,9,1001,9,1,9,4,9,3,9,101,2,9,9,4,9,99,3,9,1001,9,1,9,4,9,3,9,1001,9,2,9,4,9,3,9,101,2,9,9,4,9,3,9,101,2,9,9,4,9,3,9,1001,9,1,9,4,9,3,9,1001,9,1,9,4,9,3,9,1001,9,1,9,4,9,3,9,102,2,9,9,4,9,3,9,101,2,9,9,4,9,3,9,1001,9,2,9,4,9,99,3,9,1002,9,2,9,4,9,3,9,1001,9,2,9,4,9,3,9,102,2,9,9,4,9,3,9,1002,9,2,9,4,9,3,9,102,2,9,9,4,9,3,9,101,2,9,9,4,9,3,9,1002,9,2,9,4,9,3,9,1001,9,2,9,4,9,3,9,102,2,9,9,4,9,3,9,1002,9,2,9,4,9,99,3,9,101,1,9,9,4,9,3,9,101,1,9,9,4,9,3,9,101,2,9,9,4,9,3,9,102,2,9,9,4,9,3,9,1001,9,2,9,4,9,3,9,101,1,9,9,4,9,3,9,102,2,9,9,4,9,3,9,1001,9,1,9,4,9,3,9,101,1,9,9,4,9,3,9,1002,9,2,9,4,9,99"
# raw_d = "3,52,1001,52,-5,52,3,53,1,52,56,54,1007,54,5,55,1005,55,26,1001,54,-5,54,1105,1,12,1,53,54,53,1008,54,0,55,1001,55,1,55,2,53,55,53,4,53,1001,56,-1,56,1005,56,6,99,0,0,0,0,10"

d = [int(x) for x in raw_d.split(",")]


def opcode_add(opcode, pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    else:
        operator_2 = data[pos + 2]

    return operator_1 + operator_2


def opcode_mult(opcode, pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    else:
        operator_2 = data[pos + 2]

    return operator_1 * operator_2


def opcode_input(opcode, pos, data, ID):
    return ID


def opcode_output(opcode, pos, data):
    if opcode[-3] == "0":
        # print(data[data[pos + 1]])
        return data[data[pos + 1]]
    else:
        # print(data[pos + 1])
        return data[pos + 1]


def opcode_jump_true(opcode, pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    else:
        operator_2 = data[pos + 2]

    if operator_1 != 0:
        return operator_2
    else:
        return pos + 3


def opcode_jump_false(opcode, pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    else:
        operator_2 = data[pos + 2]

    if operator_1 == 0:
        return operator_2
    else:
        return pos + 3


def opcode_less_than(opcode, pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    else:
        operator_2 = data[pos + 2]
    if operator_1 < operator_2:
        return 1
    else:
        return 0


def opcode_equals(opcode, pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    else:
        operator_2 = data[pos + 2]
    if operator_1 == operator_2:
        return 1
    else:
        return 0


def day7(phase_b=True):
    data = d.copy()
    pos = 0
    ss = 0
    while data[pos] != 99:
        opcode = "0" * 10 + str(data[pos])
        if opcode[-1] == "1":
            data[data[pos + 3]] = opcode_add(opcode, pos, data)
            pos += 4
        if opcode[-1] == "2":
            data[data[pos + 3]] = opcode_mult(opcode, pos, data)
            pos += 4
        if opcode[-1] == "3":
            if phase_b:
                ID = phase[amplifier]
                phase_b = False
            else:
                ID = output
            data[data[pos + 1]] = opcode_input(opcode, pos, data, ID)
            pos += 2
        if opcode[-1] == "4":
            ss = opcode_output(opcode, pos, data)
            pos += 2
        if opcode[-1] == "5":
            pos = opcode_jump_true(opcode, pos, data)
        if opcode[-1] == "6":
            pos = opcode_jump_false(opcode, pos, data)
        if opcode[-1] == "7":
            data[data[pos + 3]] = opcode_less_than(opcode, pos, data)
            pos += 4
        if opcode[-1] == "8":
            data[data[pos + 3]] = opcode_equals(opcode, pos, data)
            pos += 4
    return ss


# Part 1
from itertools import permutations

sols = []
phases = list(permutations(range(5), 5))

for phase in phases:
    output = 0
    for amplifier in range(5):
        output = day7()
    sols.append(output)

max(sols)
# Out:
# 17440

# %%
def day7_part2(amplifier):
    data = datas[amplifier]
    pos = poss[amplifier]
    ss = output

    if pos == 0:
        phase_b = True
    else:
        phase_b = False

    while data[pos] != 99:
        opcode = "0" * 10 + str(data[pos])
        if opcode[-1] == "1":
            data[data[pos + 3]] = opcode_add(opcode, pos, data)
            pos += 4
        if opcode[-1] == "2":
            data[data[pos + 3]] = opcode_mult(opcode, pos, data)
            pos += 4
        if opcode[-1] == "3":
            # print(amplifier,ss)
            if phase_b:
                ID = phase[amplifier]
                phase_b = False
                data[data[pos + 1]] = opcode_input(opcode, pos, data, ID)
                pos += 2
            else:
                ID = ss
                data[data[pos + 1]] = opcode_input(opcode, pos, data, ID)
                pos += 2

        if opcode[-1] == "4":
            ss = opcode_output(opcode, pos, data)
            pos += 2
            break
        if opcode[-1] == "5":
            pos = opcode_jump_true(opcode, pos, data)
        if opcode[-1] == "6":
            pos = opcode_jump_false(opcode, pos, data)
        if opcode[-1] == "7":
            data[data[pos + 3]] = opcode_less_than(opcode, pos, data)
            pos += 4
        if opcode[-1] == "8":
            data[data[pos + 3]] = opcode_equals(opcode, pos, data)
            pos += 4
    poss[amplifier] = pos
    return ss


# Part2
sols = []
phases = list(permutations(range(5, 10), 5))

for phase in phases:

    datas = [d.copy(), d.copy(), d.copy(), d.copy(), d.copy()]
    poss = [0, 0, 0, 0, 0]
    old_output = -1
    output = 0
    while old_output != output:
        old_output = output
        for amplifier in range(5):
            # print(amplifier,poss)
            # print(amplifier,output)
            output = day7_part2(amplifier)

    sols.append(output)
max(sols)
# Out:
# 27561242
