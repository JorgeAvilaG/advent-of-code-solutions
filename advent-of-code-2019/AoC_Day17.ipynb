d = [int(x) for x in raw_d.split(",")]
d.extend([0] * 2000)


def opcode_add(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    return operator_1 + operator_2


def opcode_mult(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    return operator_1 * operator_2


def opcode_input(opcode, pos, data):
    return ID.pop(0)


def opcode_output(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        return data[data[pos + 1]]
    elif opcode[-3] == "2":
        return data[data[pos + 1] + r_pos]
    else:
        return data[pos + 1]


def opcode_jump_true(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    if operator_1 != 0:
        return operator_2
    else:
        return pos + 3


def opcode_jump_false(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]

    if operator_1 == 0:
        return operator_2
    else:
        return pos + 3


def opcode_less_than(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]
    if operator_1 < operator_2:
        return 1
    else:
        return 0


def opcode_equals(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        operator_1 = data[data[pos + 1]]
    elif opcode[-3] == "2":
        operator_1 = data[data[pos + 1] + r_pos]
    else:
        operator_1 = data[pos + 1]

    if opcode[-4] == "0":
        operator_2 = data[data[pos + 2]]
    elif opcode[-4] == "2":
        operator_2 = data[data[pos + 2] + r_pos]
    else:
        operator_2 = data[pos + 2]
    if operator_1 == operator_2:
        return 1
    else:
        return 0


def rel_base(opcode, pos, r_pos, data):
    if opcode[-3] == "0":
        return data[data[pos + 1]]
    elif opcode[-3] == "2":
        return data[data[pos + 1] + r_pos]
    else:
        return data[pos + 1]


def day5():
    counter = 0
    data = d.copy()
    pos = 0
    r_pos = 0

    sol = []

    while data[pos] != 99:
        opcode = "0" * 10 + str(data[pos])
        if opcode[-1] == "1":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_add(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_add(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "2":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_mult(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_mult(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "3":
            if opcode[-3] == "0":
                data[data[pos + 1]] = opcode_input(opcode, pos, data)
            elif opcode[-3] == "2":
                data[data[pos + 1] + r_pos] = opcode_input(opcode, pos, data)
            pos += 2
        if opcode[-1] == "4":
            sol.append(opcode_output(opcode, pos, r_pos, data))
            pos += 2
        if opcode[-1] == "5":
            pos = opcode_jump_true(opcode, pos, r_pos, data)
        if opcode[-1] == "6":
            pos = opcode_jump_false(opcode, pos, r_pos, data)
        if opcode[-1] == "7":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_less_than(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_less_than(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "8":
            if opcode[-5] == "0":
                data[data[pos + 3]] = opcode_equals(opcode, pos, r_pos, data)
            elif opcode[-5] == "2":
                data[data[pos + 3] + r_pos] = opcode_equals(opcode, pos, r_pos, data)
            pos += 4
        if opcode[-1] == "9":
            r_pos += rel_base(opcode, pos, r_pos, data)
            pos += 2

    return sol


ID = [
    65,
    44,
    66,
    44,
    65,
    44,
    66,
    44,
    67,
    44,
    67,
    44,
    66,
    44,
    65,
    44,
    66,
    44,
    67,
    10,
    76,
    44,
    52,
    44,
    82,
    44,
    56,
    44,
    76,
    44,
    54,
    44,
    76,
    44,
    49,
    48,
    10,
    76,
    44,
    54,
    44,
    82,
    44,
    56,
    44,
    82,
    44,
    49,
    48,
    44,
    76,
    44,
    54,
    44,
    76,
    44,
    54,
    10,
    76,
    44,
    52,
    44,
    76,
    44,
    52,
5,1,1,1,5,1,8,7,7,7,1,1,5,1,14,1,15,1,5,1,14,1,15,1,5,5,10,1,15,1,20,1,1,7,7,7,14,1,1,1,5,1,13,1,10,11,1,1,13,1,10,1,3,1,1,1,3,1,1,1,13,1,10,1,3,1,1,1,3,1,1,1,7,11,6,1,3,1,1,1,3,1,1,1,7,1,5,1,3,1,6,5,1,5,1,1,7,1,5,1,3,1,18,1,7,1,5,1,3,1,18,1,3,11,3,1,18,1,3,1,3,1,9,1,18,9,1,9,22,1,5,1,30,1,5,1,30,1,5,1,30,7,8"
d = [int(x) for x in raw_d.split(",")]
d.extend([0] * 2000)
i = 1
j = 1

a = day5()

for item in a:
    if item == 35:
        matrix[j, i] = 1
        i += 1
    elif item == 94:  # ^
        matrix[j, i] = 5
        # print('position vacuum:',j,i)
        i += 1

    elif item == 10:
        j += 1
        i = 1

    else:
        i += 1


total = 0
for j in range(1, matrix.shape[0] - 1):
    for i in range(1, matrix.shape[1] - 1):
        if matrix[j, i] == 1:
            if (
                matrix[j + 1, i]
                + matrix[j - 1, i]
                + matrix[j, i - 1]
                + matrix[j, i + 1]
            ) == 4:
                total += (j - 1) * (i - 1)
print("Solution Part 1:", total)
# Out:
# Solution Part 1: 3192

# %%
plt.imshow(matrix, cmap="hot")
plt.show()

# %%
# Part 2. Calculating it manually
y = 0
x = -1
d = [(-1, 0), (0, 1), (1, 0), (0, -1)]
pd = 3
py = 17
px = 37
counter = 0
sol = ["L"]
while True:
    if matrix[py + y, px + x] == 1:
        counter += 1
        py += y
        px += x
    else:
        sol.append(str(counter))
        # print(counter)
        counter = 0
        right = d[(pd + 1) % 4]
        left = d[(pd - 1) % 4]
        if matrix[py + right[0], px + right[1]] == 1:
            sol.append("R")  # print('R')
            y = right[0]
            x = right[1]
            pd = (pd + 1) % 4
        elif matrix[py + left[0], px + left[1]] == 1:
            sol.append("L")  # print('L')
            y = left[0]
            x = left[1]
            pd = (pd - 1) % 4
        else:
            break

",".join(sol)
# Out:
# 'L,4,R,8,L,6,L,10,L,6,R,8,R,10,L,6,L,6,L,4,R,8,L,6,L,10,L,6,R,8,R,10,L,6,L,6,L,4,L,4,L,10,L,4,L,4,L,10,L,6,R,8,R,10,L,6,L,6,L,4,R,8,L,6,L,10,L,6,R,8,R,10,L,6,L,6,L,4,L,4,L,10'

# %%
# a = L,4,R,8,L,6,L,10 #76,44,52,44,82,44,56,44,76,44,54,44,76,44,49,48,10
# b = L,6,R,8,R,10,L,6,L,6 #76,44,54,44,82,44,56,44,82,44,49,48,44,76,44,54,44,76,44,54,10
# c = L,4,L,4,L,10   #76,44,52,44,76,44,52,44,76,44,49,48,10
# a,b,a,b,c,c,b,a,b,c #65,44,66,44,65,44,66,44,67,44,67,44,66,44,65,44,66,44,67,10
# n 110,10
# ID = 65,44,66,44,65,44,66,44,67,44,67,44,66,44,65,44,66,44,67,10,76,44,52,44,82,44,56,44,76,44,54,44,76,44,49,48,10,76,44,54,44,82,44,56,44,82,44,49,48,44,76,44,54,44,76,44,54,10,76,44,52,44,76,44,52,44,76,44,49,48,10,110,10
